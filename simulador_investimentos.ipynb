# %% [markdown]
# <a href="https://colab.research.google.com/github/cath-coder/algoritmos-python-pit/blob/main/simulador_investimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
salario = float(input('Digite se salário: R$ '))

print('Essenciais (50%): R$', salario * 0.50)
print('Lazer (20%): R$', salario * 0.20)
print('Investimento (30%): R$', salario * 0.30)

print('\n--- SIMULADOR DE INVESTIMENTO ---')

aporte_inicial = float(input('Aporte inicial: R$ '))
aporte_mensal = float(input('Aporte mensal: R$ '))
taxa_anual = float(input('Taxa de juros anual: '))
anos = int(input('Quantidade de anos investidos:'))

taxa_mensal = ((1 + taxa_anual) ** (1/12)) - 1
meses = anos * 12

saldo = aporte_inicial
total_investido = aporte_inicial

for m in range(1, meses + 1):
  saldo = (saldo * (1 + taxa_mensal)) + aporte_mensal
  total_investido += aporte_mensal

  if m % 12 == 0:
    print(f'Ano {m // 12}: R$ {saldo:.2f}')

print('\n-----------------------------------')
print('Total do seu bolso:', total_investido)
print('Total acumulado com juros:', round(saldo,2))
print('Rendimento aproximado por mês:', round(saldo * 0.01, 2))
print('\n-----------------------------------')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1228/3588937219.py in <cell line: 0>()
# ----> 1 salario = float(input('Digite se salário: R$ '))
#       2
#       3 print('Essenciais (50%): R$', salario * 0.50)
#       4 print('Lazer (20%): R$', salario * 0.20)
#       5 print('Investimento (30%): R$', salario * 0.30)
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
