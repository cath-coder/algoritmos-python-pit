# %% [markdown]
# <a href="https://colab.research.google.com/github/cath-coder/algoritmos-python-pit/blob/main/Comandos_de_decis%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

num = int(input('Digite um número:'))

if num <=10:
  print(num)

else:
  print('Tente novamente.')

# %%
#2

num = int(input('Digite um número:'))

if num % 2 == 0:
  print('O número' ,num, 'é par.')

else:
  print('O número' ,num, 'é ímpar.')

# %%
#3

num1 = float(input('Digite o primeiro número:'))
num2 = float(input('Digite o segundo número:'))

if num1 > num2:
  print('O primeiro número é maior.')

elif num2 > num1:
  print('O segundo número é maior.')

# %%
#4

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o segundo número:'))
c = int(input('Digite o terceiro número:'))

soma = a + b + c

if soma =>100:
  print(soma)

else:
  print('Tente novamente.')

# %%
#5

num = int(input('Digite um número:'))

mult = num * 2

if mult > 30:
  print(mult)

else:
  print('Tente novamente.')

# %%
#6

nome = input('Digite seu nome:')
idade = int(input('Digite sua idade:'))

if idade <= 25:
  print(f'{nome} aceita')

# %%
#7
 num = int(input("Digite um número:"))

if num <0:
  print('Número invalido.')

else:
  print('Número válido.')

# %%
#8

import math
num = float(input('Digite um número:'))

if num >=0:
  print(f'Quadrado do número: {num**2}')

else:
  print(f'Raiz quadrada:', math.sqrt(abs(num)))

# %%
#9

num = float(input('Digite um número:'))

if 20< num <90:
  print('O número', num, 'está dentro do intervalo de 20 a 90.')

else:
  print('O número', num, 'NÃO está dentro do intervalo de 20 a 90.')

# %%
#10

import math
num1 = float(input('Digite o primeiro número:'))
num2 = float(input('Digite o segundo número')))

if num1 == num2:
  print('Cubo:', num1 ***3)
elif num1 < num2:
  print('Quadrado do menor:', num1 **2)
  print('Raiz do maior:', math.sqrt(num2))
else:
  print('Quadrado do maior:', num2 **2)
  print('Raiz do menor:', math.sqrt(num1))

# %%
#11

n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))

soma = n1 + n2

if soma > 20:
    resultado = soma + 8
else:
    resultado = soma - 5

print(f"Resultado final: {resultado}")

# %%
#12

salario = float(input("Digite o salário do trabalhador: R$ "))
prestacao = float(input("Digite o valor da prestação: R$ "))

if prestacao > (0.20 * salario):
    print("Empréstimo não concedido.")
else:
    print("Empréstimo concedido.")

# %%
#13

numero = int(input("Digite um número: "))

div3 = (numero % 3 == 0)
div5 = (numero % 5 == 0)

if (div3 or div5) and not (div3 and div5):
    print("Divisível por 3 ou 5 (mas não ambos)")
else:
    print("Não atende à condição")

# %%
#14

a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))
c = float(input("Digite o terceiro número: "))

if a <= b and a <= c:
    if b <= c:
        print(a, b, c)
    else:
        print(a, c, b)
elif b <= a and b <= c:
    if a <= c:
        print(b, a, c)
    else:
        print(b, c, a)
else:
    if a <= b:
        print(c, a, b)
    else:
        print(c, b, a)

# %%
#15

h = float(input("Digite a altura em metros: "))
sexo = input("Digite o sexo (M/F): ")

if sexo == "M" or sexo == "m":
    print("Peso ideal:", (72.7 * h) - 58)
else:
    print("Peso ideal:", (62.1 * h) - 47)

# %%
#16


valor = float(input("Digite o valor de compra: "))

if valor < 20:
    print("Valor de venda:", valor * 1.45)
else:
    print("Valor de venda:", valor * 1.30)

# %%
#17


idade = int(input("Digite a idade: "))

if idade >= 5 and idade <= 7:
    print("Infantil A")
elif idade >= 8 and idade <= 10:
    print("Infantil B")
elif idade >= 11 and idade <= 13:
    print("Juvenil A")
elif idade >= 14 and idade <= 17:
    print("Juvenil B")
else:
    print("Não pertence a nenhuma categoria")

# %%
#18

salario = float(input("Digite o salário bruto: "))

if salario <= 600:
    print("Isento")
elif salario <= 1200:
    print("Desconto INSS:", salario * 0.20)
elif salario <= 2000:
    print("Desconto INSS:", salario * 0.25)
else:
    print("Desconto INSS:", salario * 0.30)

# %%
#19

ano_atual = int(input("Digite o ano atual: "))
ano_nasc = int(input("Digite o ano de nascimento: "))

idade = ano_atual - ano_nasc

if idade < 16:
    print("Não é eleitor")
elif idade >= 18 and idade <= 65:
    print("Eleitor obrigatório")
else:
    print("Eleitor facultativo")

# %%
#20

idade = int(input("Digite a idade: "))

if idade >= 65:
    print("Pessoa idosa")
elif idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")

# %%
#21


x = float(input("Digite x: "))

if x <= 1:
    print("f(x) =", 1)
elif x <= 2:
    print("f(x) =", 2)
elif x <= 3:
    print("f(x) =", x ** 2)
else:
    print("f(x) =", x ** 3)

# %%
#22


nome = input("Digite o nome do cliente: ")
valor = float(input("Digite o valor da compra: "))

if valor <= 200:
    desconto = valor * 0.10
elif valor <= 500:
    desconto = valor * 0.15
else:
    desconto = valor * 0.20

print("Cliente:", nome)
print("Valor da compra:", valor)
print("Desconto:", desconto)
print("Total a pagar:", valor - desconto)

# %%
#23


mes = int(input("Digite o número do mês (1 a 12): "))

if mes == 1:
    print("Janeiro")
elif mes == 2:
    print("Fevereiro")
elif mes == 3:
    print("Março")
elif mes == 4:
    print("Abril")
elif mes == 5:
    print("Maio")
elif mes == 6:
    print("Junho")
elif mes == 7:
    print("Julho")
elif mes == 8:
    print("Agosto")
elif mes == 9:
    print("Setembro")
elif mes == 10:
    print("Outubro")
elif mes == 11:
    print("Novembro")
elif mes == 12:
    print("Dezembro")
else:
    print("Mês inválido")
